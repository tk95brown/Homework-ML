# %% [markdown]
# **Fin 485**
# **Diether**
# **Problem Set**
# **Intro to Python/Pandas**
#
# **Overview**
#
# This problem set is designed to introduce you to using Python for empirical analysis. You can discuss this problem set and get coding help from other students in the class. But you must prepare your own answers (i.e., print out your Jupyter notebook). This assignment will be graded based on effort. Do your best, don’t worry if you can’t answer all the questions. We will discuss the problem set in class.
#
# **Turning in the assignment**
#
# Please email me your Jupyter notebook before class.
#
# **General Python Programming**
#
# 1. From *Think Python*. Write a function named `right_justify` that takes a string named `s` as a parameter and prints the string with enough leading spaces so that the last letter of the string is in column 70 of the display.
# ```python
# >>> right_justify('monty')
#                                                                  monty
# ```
# Hint: Use string concatenation and repetition. Also, Python provides a built-in function called `len` that returns the length of a string, so the value of `len('monty')` is 5.<br>
#
# **Data Analysis with Python/Pandas**
#
# You can download the data for this problem set here: [U.S. Baby Name Data](http://diether.org/prephd/02-names_1997-2016.csv). There is also a link to the data on the schedule page of *Learning Suite*. The data are names (with at least five occurrences) of babies born in the United States by year from 1997 to 2016. The data are in a csv file. First, read the data into python using Pandas. Use the documentation on the Pandas webpage to help you:
#
# [Pandas Documentation](http://pandas.pydata.org/)
#
# To read the data in Python using Pandas take a look at the `read_csv` command (or how I used it in my Python/Pandas example last class).
#
# **Tasks and Questions**
#
# 1. Print out the first 10 observations of the data.<br><br>
#
# 2. In how many years does the name "Jimmer" show up in the data?<br><br>
#
# 3. In which year was the name "Jennifer" most popular?<br><br>
#
# 4. Compute the number of times the name “Karl” was used as a baby name according to the data (sum of the births over the 20 years). Note, there will be 20 observations for Karl in the data; the number of births named Karl each year. The `births` variable tells you the number of births named Karl for that year.<br><br>
#
# 5. Harder questions: questions 5-7 increase the difficulty. Do your best. Hint, use the `groupby` command. Compute the number of male and female births in the data.<br><br>
#
# 6. Compute the number of male and female names in the data.<br><br>
#
# 7. Compute the number of births by year: 1997–2016.<br><br>

# %% [markdown]
# **General Programming**
# **Question 1**
#
# From Think Python. Write a function named right_justify that takes a string named s as a parameter and prints the string with enough leading spaces so that the last letter of the string is in column 70 of the display.

# %%
>>> def right_justify(s):
    s = " " * (70 - len(s)) + s
    print(s)

# %%
s = "test"
right_justify(s)
# Out:
#                                                                   test

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('http://diether.org/prephd/02-names_1997-2016.csv')

# %% [markdown]
# **Data Analysis**
# **Question 1**
#
# Print out the first 10 observations of the data.

# %%
    df.head(10)
# Out:
#         name sex  births  year
# 0      Emily   F   25731  1997
# 1    Jessica   F   21043  1997
# 2     Ashley   F   20894  1997
# 3      Sarah   F   20690  1997
# 4     Hannah   F   20586  1997
# 5   Samantha   F   20169  1997
# 6     Taylor   F   19503  1997
# 7     Alexis   F   17172  1997
# 8  Elizabeth   F   15411  1997
# 9    Madison   F   15187  1997

# %%
df[0:10]
# Out:
#         name sex  births  year
# 0      Emily   F   25731  1997
# 1    Jessica   F   21043  1997
# 2     Ashley   F   20894  1997
# 3      Sarah   F   20690  1997
# 4     Hannah   F   20586  1997
# 5   Samantha   F   20169  1997
# 6     Taylor   F   19503  1997
# 7     Alexis   F   17172  1997
# 8  Elizabeth   F   15411  1997
# 9    Madison   F   15187  1997

# %%
df.tail(10)
# Out:
#           name sex  births  year
# 642216    Zinn   M       5  2016
# 642217   Zirui   M       5  2016
# 642218    Ziya   M       5  2016
# 642219  Ziyang   M       5  2016
# 642220    Zoel   M       5  2016
# 642221  Zolton   M       5  2016
# 642222  Zurich   M       5  2016
# 642223  Zyahir   M       5  2016
# 642224    Zyel   M       5  2016
# 642225   Zylyn   M       5  2016

# %% [markdown]
# **Question 2**
#
# In how many years does the name "Jimmer" show up in the data?

# %%
df[df['name']=='Jimmer']
# Out:
#           name sex  births  year
# 470408  Jimmer   M       9  2011

# %%
print ('Only in the year 2011 did the name \'Jimmer\' appear.' )
# Out:
# Only in the year 2011 did the name 'Jimmer' appear.

# %%
df.loc[df['name'] == 'Jimmer',] 
#df.loc[df['name'] == 'Jimmer', 'year'].count()
# .loc function also helps with rows annnd columns
# Out:
#           name sex  births  year
# 470408  Jimmer   M       9  2011

# %% [markdown]
# **Question 3**
#
# In which year was the name "Jennifer" most popular?

# %%
df[df['name']=='Jennifer']
# Out:
#             name sex  births  year
# 17      Jennifer   F   11837  1997
# 18438   Jennifer   M      37  1997
# 26984   Jennifer   F   10687  1998
# 46605   Jennifer   M      26  1998
# 54876   Jennifer   F   10610  1999
# 74767   Jennifer   M      28  1999
# 83425   Jennifer   F    9385  2000
# 103884  Jennifer   M      32  2000
# 113188  Jennifer   F    8920  2001
# 134486  Jennifer   M      26  2001
# 143451  Jennifer   F    8536  2002
# 164801  Jennifer   M      27  2002
# 174014  Jennifer   F    7564  2003
# 196919  Jennifer   M      18  2003
# 205194  Jennifer   F    6541  2004
# 227904  Jennifer   M      23  2004
# 237233  Jennifer   F    5832  2005
# 261772  Jennifer   M      15  2005
# 269775  Jennifer   F    5265  2006
# 295166  Jennifer   M      16  2006
# 303857  Jennifer   F    4648  2007
# 334611  Jennifer   M       7  2007
# 338808  Jennifer   F    3791  2008
# 365056  Jennifer   M      15  2008
# 373878  Jennifer   F    2986  2009
# 407255  Jennifer   M       5  2009
# 408574  Jennifer   F    2616  2010
# 439617  Jennifer   M       6  2010
# 442628  Jennifer   F    2276  2011
# 473481  Jennifer   M       6  2011
# 476527  Jennifer   F    1921  2012
# 508913  Jennifer   M       5  2012
# 510239  Jennifer   F    1688  2013
# 543470  Jennifer   F    1514  2014
# 573578  Jennifer   M       6  2014
# 476527  Jennifer   F    1921  2012
# 442628  Jennifer   F    2276  2011
# 408574  Jennifer   F    2616  2010
# 373878  Jennifer   F    2986  2009
# 338808  Jennifer   F    3791  2008
# 303857  Jennifer   F    4648  2007
# 269775  Jennifer   F    5265  2006
# 237233  Jennifer   F    5832  2005
# 205194  Jennifer   F    6541  2004
# 174014  Jennifer   F    7564  2003
# 143451  Jennifer   F    8536  2002
# 113188  Jennifer   F    8920  2001
# 83425   Jennifer   F    9385  2000
# 54876   Jennifer   F   10610  1999
# 26984   Jennifer   F   10687  1998
# 17      Jennifer   F   11837  1997

# %%
# %matplotlib inline
import matplotlib as plt
plt.style.use('ggplot')

jen = df.query("name == 'Jennifer' and sex == 'F'")
jen.plot(y='births',x='year')

# %% [markdown]
# **Question 4**
#
# Compute the number of times the name “Karl” was used as a name in the data (sum of the
# births over the 20 years). Note, that will be 20 observations for Karl. One for each year of the data. The `births` variable tells you the number of births named Karl for that year.

# %%
df[df['name'] == 'Karl'].sum()
# Out:
# name      KarlKarlKarlKarlKarlKarlKarlKarlKarlKarlKarlKa...
# sex                                    MMMMMMMMMMMMMMMMMMMM
# births                                                 5308
# year                                                  40130
# dtype: object

# %% [markdown]
# There are 5308 births attributed to the name "Karl" over the 20 year period.

# %%
df.loc[df['name'] == 'Karl','births'].sum()
# Out:
# 5308

# %% [markdown]
# **Question 5**
#
# Compute the number of male and female births in the data.

# %%
df[df['sex'] == 'M'].sum()
#df[df['sex'] == 'F']
# Out:
# name      MichaelJacobMatthewChristopherJoshuaNicholasBr...
# sex       MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# births                                             38915049
# year                                              534549247
# dtype: object

# %%
df.groupby('sex')[['births']].sum()
# Out:
#        births
# sex
# F    36057581
# M    38915049

# %%
df[df['sex'] == 'F'].sum()
# Out:
# name      EmilyJessicaAshleySarahHannahSamanthaTaylorAle...
# sex       FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...
# births                                             36057581
# year                                              754287949
# dtype: object

# %% [markdown]
# There were 38915049 male births and 36057581 female births

# %% [markdown]
# **Question 6**
#
# Compute the number of male and female names in the data.

# %%
df[df['sex'] == 'F'].count()
# Out:
# name      375874
# sex       375874
# births    375874
# year      375874
# dtype: int64

# %%
df.groupby('sex')[['name']].count()
# Out:
#        name
# sex
# F    375874
# M    266352

# %%
df[df['sex'] == 'M'].count()
# Out:
# name      266352
# sex       266352
# births    266352
# year      266352
# dtype: int64

# %%
df[df['sex'] == 'M'].name.unique().size
# Out:
# 30485

# %%
df[df['sex'] == 'F'].name.unique().size
# Out:
# 44740

# %% [markdown]
# There are 30485 unique male names and 44740 unique female names.

# %% [markdown]
# **Question 7**
#
# Compute the number of births by year: 1997–2016.

# %%
for x in range(1997, 2017):
    print("Year: ") 
    print(x)
    print(df[df['year'] == x].count())
    print("\n")
# Out:
# Year:
# 1997
# name      26965
# sex       26965
# births    26965
# year      26965
# dtype: int64
#
#
# Year:
# 1998
# name      27891
# sex       27891
# births    27891
# year      27891
# dtype: int64
#
#
# Year:
# 1999
# name      28544
# sex       28544
# births    28544
# year      28544
# dtype: int64
#
#
# Year:
# 2000
# name      29763
# sex       29763
# births    29763
# year      29763
# dtype: int64
#
#
# Year:
# 2001
# name      30261
# sex       30261
# births    30261
# year      30261
# dtype: int64
#
#
# Year:
# 2002
# name      30560
# sex       30560
# births    30560
# year      30560
# dtype: int64
#
#
# Year:
# 2003
# name      31173
# sex       31173
# births    31173
# year      31173
# dtype: int64
#
#
# Year:
# 2004
# name      32035
# sex       32035
# births    32035
# year      32035
# dtype: int64
#
#
# Year:
# 2005
# name      32533
# sex       32533
# births    32533
# year      32533
# dtype: int64
#
#
# Year:
# 2006
# name      34069
# sex       34069
# births    34069
# year      34069
# dtype: int64
#
#
# Year:
# 2007
# name      34931
# sex       34931
# births    34931
# year      34931
# dtype: int64
#
#
# Year:
# 2008
# name      35045
# sex       35045
# births    35045
# year      35045
# dtype: int64
#
#
# Year:
# 2009
# name      34684
# sex       34684
# births    34684
# year      34684
# dtype: int64
#
#
# Year:
# 2010
# name      34041
# sex       34041
# births    34041
# year      34041
# dtype: int64
#
#
# Year:
# 2011
# name      33869
# sex       33869
# births    33869
# year      33869
# dtype: int64
#
#
# Year:
# 2012
# name      33684
# sex       33684
# births    33684
# year      33684
# dtype: int64
#
#
# Year:
# 2013
# name      33203
# sex       33203
# births    33203
# year      33203
# dtype: int64
#
#
# Year:
# 2014
# name      33044
# sex       33044
# births    33044
# year      33044
# dtype: int64
#
#
# Year:
# 2015
# name      33063
# sex       33063
# births    33063
# year      33063
# dtype: int64
#
#
# Year:
# 2016
# name      32868
# sex       32868
# births    32868
# year      32868
# dtype: int64

# %%
df.groupby(['year','sex'])[['births']].sum()
# Out:
#            births
# year sex
# 1997 F    1739806
#      M    1884122
# 1998 F    1765915
#      M    1910250
# 1999 F    1772632
#      M    1918809
# 2000 F    1814601
#      M    1962406
# 2001 F    1799049
#      M    1941251
# 2002 F    1795206
#      M    1939815
# 2003 F    1825359
#      M    1973434
# 2004 F    1834145
#      M    1982794
# 2005 F    1845379
#      M    1994841
# 2006 F    1898463
#      M    2052377
# 2007 F    1919408
#      M    2072139
# 2008 F    1887234
#      M    2036289
# 2009 F    1832925
#      M    1979303
# 2010 F    1772738
#      M    1913851
# 2011 F    1753500
#      M    1893230
# 2012 F    1753922
#      M    1889414
# 2013 F    1745339
#      M    1881463
# 2014 F    1768775
#      M    1901376
# 2015 F    1776538
#      M    1907211
# 2016 F    1756647
#      M    1880674

# %% [markdown]
# The births by year are listed above.
